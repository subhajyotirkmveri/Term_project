# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def count_columns_with_null_in_intervals(dataframe):
    # Initialize counters for each interval
    interval_25_33 = 0
    interval_0_25 = 0
    interval_33_50 = 0
    interval_50_75 = 0
    interval_above_75 = 0
    
    # Iterate through all the columns except the first two
    for column_name in dataframe.columns[2:]:
        column_data = dataframe[column_name]
        
        # Calculate the total number of null values in the column
        total_null = column_data.isna().sum()
        
        # Calculate the percentage of null values in the column
        percentage_null = (total_null / len(column_data)) * 100
        
        # Check which interval the percentage falls into and update the corresponding counter
        if 25 <= percentage_null <= 33:
            interval_25_33 += 1
        elif 0 <= percentage_null < 25:
            interval_0_25 += 1
        elif 33 < percentage_null <= 50:
            interval_33_50 += 1
        elif 50 < percentage_null <= 75:
            interval_50_75 += 1
        else:
            interval_above_75 += 1
    
    return {
        '25-33%': interval_25_33,
        '0-25%': interval_0_25,
        '33-50%': interval_33_50,
        '50-75%': interval_50_75,
        'Above 75%': interval_above_75
    }

# %% [markdown]
# # For Delhi

# %%
import pandas as pd
df = pd.read_csv("./Chosen_state_2023_sep_merge_sentinel5p_Hcho/Delhi_sep_Hcho.csv")


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
# Out:
# Columns with null values in 25-33% interval: 4
# Columns with null values in 0-25% interval: 26
# Columns with null values in 33-50% interval: 0
# Columns with null values in 50-75% interval: 0
# Columns with null values in Above 75% interval: 0

# %%
# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Plot the counts for each interval
intervals = list(interval_counts.keys())
values = list(interval_counts.values())

plt.pie(values, labels=intervals, autopct='%1.1f%%', startangle=150, colors=['skyblue', 'orange', 'green', 'red', 'purple'])
plt.title('Null Value Intervals for Columns in DataFrame')
plt.show()

# %% [markdown]
# # For west Bengal

# %%
import pandas as pd
df = pd.read_csv("./Chosen_state_2023_sep_merge_sentinel5p_Hcho/WB_sep_Hcho.csv")


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
# Out:
# Columns with null values in 25-33% interval: 2
# Columns with null values in 0-25% interval: 27
# Columns with null values in 33-50% interval: 1
# Columns with null values in 50-75% interval: 0
# Columns with null values in Above 75% interval: 0

# %%
# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Plot the counts for each interval
intervals = list(interval_counts.keys())
values = list(interval_counts.values())

plt.pie(values, labels=intervals, autopct='%1.1f%%', startangle=150, colors=['skyblue', 'orange', 'green', 'red', 'purple'])
plt.title('Null Value Intervals for Columns in DataFrame')
plt.show()

# %% [markdown]
# # For Karnataka

# %%
import pandas as pd
df = pd.read_csv("./Chosen_state_2023_sep_merge_sentinel5p_Hcho/karnataka_sep_Hcho.csv")


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
# Out:
# Columns with null values in 25-33% interval: 1
# Columns with null values in 0-25% interval: 29
# Columns with null values in 33-50% interval: 0
# Columns with null values in 50-75% interval: 0
# Columns with null values in Above 75% interval: 0

# %%
# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Plot the counts for each interval
intervals = list(interval_counts.keys())
values = list(interval_counts.values())

plt.pie(values, labels=intervals, autopct='%1.1f%%', startangle=150, colors=['skyblue', 'orange', 'green', 'red', 'purple'])
plt.title('Null Value Intervals for Columns in DataFrame')
plt.show()

# %% [markdown]
# # For Maharashtra

# %%
import pandas as pd
df = pd.read_csv("./Chosen_state_2023_sep_merge_sentinel5p_Hcho/Maharashtra_sep_Hcho.csv")


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
# Out:
# Columns with null values in 25-33% interval: 2
# Columns with null values in 0-25% interval: 28
# Columns with null values in 33-50% interval: 0
# Columns with null values in 50-75% interval: 0
# Columns with null values in Above 75% interval: 0

# %%
# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Plot the counts for each interval
intervals = list(interval_counts.keys())
values = list(interval_counts.values())

plt.pie(values, labels=intervals, autopct='%1.1f%%', startangle=150, colors=['skyblue', 'orange', 'green', 'red', 'purple'])
plt.title('Null Value Intervals for Columns in DataFrame')
plt.show()

# %% [markdown]
# # For Orissa

# %%
import pandas as pd
df = pd.read_csv("./Chosen_state_2023_sep_merge_sentinel5p_Hcho/Orissa_sep_Hcho.csv")


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
# Out:
# Columns with null values in 25-33% interval: 2
# Columns with null values in 0-25% interval: 28
# Columns with null values in 33-50% interval: 0
# Columns with null values in 50-75% interval: 0
# Columns with null values in Above 75% interval: 0

# %%
# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Plot the counts for each interval
intervals = list(interval_counts.keys())
values = list(interval_counts.values())

plt.pie(values, labels=intervals, autopct='%1.1f%%', startangle=150, colors=['skyblue', 'orange', 'green', 'red', 'purple'])
plt.title('Null Value Intervals for Columns in DataFrame')
plt.show()

# %% [markdown]
# # For Tamilnadu

# %%
import pandas as pd
df = pd.read_csv("./Chosen_state_2023_sep_merge_sentinel5p_Hcho/Tamilnadu_sep_Hcho.csv")


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
# Out:
# Columns with null values in 25-33% interval: 0
# Columns with null values in 0-25% interval: 30
# Columns with null values in 33-50% interval: 0
# Columns with null values in 50-75% interval: 0
# Columns with null values in Above 75% interval: 0

# %%
# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Plot the counts for each interval
intervals = list(interval_counts.keys())
values = list(interval_counts.values())

plt.pie(values, labels=intervals, autopct='%1.1f%%', startangle=150, colors=['skyblue', 'orange', 'green', 'red', 'purple'])
plt.title('Null Value Intervals for Columns in DataFrame')
plt.show()

# %% [markdown]
# # For Gujrat

# %%
import pandas as pd
df = pd.read_csv("./Chosen_state_2023_sep_merge_sentinel5p_Hcho/Gujrat_sep_Hcho.csv")


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
# Out:
# Columns with null values in 25-33% interval: 2
# Columns with null values in 0-25% interval: 28
# Columns with null values in 33-50% interval: 0
# Columns with null values in 50-75% interval: 0
# Columns with null values in Above 75% interval: 0

# %%
# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Plot the counts for each interval
intervals = list(interval_counts.keys())
values = list(interval_counts.values())

plt.pie(values, labels=intervals, autopct='%1.1f%%', startangle=150, colors=['skyblue', 'orange', 'green', 'red', 'purple'])
plt.title('Null Value Intervals for Columns in DataFrame')
plt.show()
