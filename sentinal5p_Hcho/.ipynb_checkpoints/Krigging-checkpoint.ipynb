# %%
import pandas as pd
import os
# !pip install pykrige
# Out:
# Requirement already satisfied: pykrige in /home/sysadm/anaconda3/lib/python3.11/site-packages (1.7.1)
# Requirement already satisfied: numpy<2,>=1.14.5 in /home/sysadm/anaconda3/lib/python3.11/site-packages (from pykrige) (1.24.3)
# Requirement already satisfied: scipy<2,>=1.1.0 in /home/sysadm/anaconda3/lib/python3.11/site-packages (from pykrige) (1.10.1)

# %% [raw]
# delhi = pd.read_csv("/home/sysadm/Downloads/sentinal5p_O3/Chosen_state_sep_merge_sentinel5p_O3/Delhi_sep_O3.csv")

# %% [raw]
# delhi

# %% [raw]
# delhi.columns.tolist()

# %% [raw]
# date_column = delhi.columns.tolist()[2:]
# date_column

# %% [raw]
# df1

# %% [raw]
# # Create a DataFrame with only latitude, longitude, and the specified date column
# df1 = delhi[['latitude', 'longitude', '2023-09-21']]
#
# # Create a DataFrame with latitude and longitude where the specified date column's values are NaN
# nan_locations_df = df1[df1['2023-09-21'].isna()][['latitude', 'longitude']]
# nan_locations_df

# %% [raw]
# # Create a DataFrame with latitude, longitude, and the specified date column excluding NaN values
# pollutant_df = df1.dropna(subset=['2023-09-21'])[['latitude', 'longitude', '2023-09-21']]
# pollutant_df

# %%
import numpy as np
import pandas as pd
from pykrige.ok import OrdinaryKriging

# %% [raw]
# # Prepare the data for Ordinary Kriging
# lons = np.array(pollutant_df['longitude'])
# lats = np.array(pollutant_df['latitude'])
# zdata = np.array(pollutant_df['2023-09-21'])

# %%
nlags=20

# %% [raw]
# # Perform Ordinary Kriging
# OK = OrdinaryKriging(lons, lats, zdata, variogram_model='linear', verbose=True, enable_plotting=False, nlags=nlags)
# grid_lon = np.array(nan_locations_df["longitude"])
# grid_lat = np.array(nan_locations_df["latitude"])
# z1, ss1 = OK.execute('grid', grid_lon, grid_lat)

# %% [raw]
# nan_locations_df['2023-09-21'] = z1[0]
# nan_locations_df

# %% [raw]
# # Merge the two DataFrames based on their indices
# merged_df = pd.concat([pollutant_df, nan_locations_df], ignore_index=False)
# merged_df

# %% [raw]
# # Sort the DataFrame by ascending index
# merged_df = merged_df.sort_index(ascending=True)
# merged_df

# %% [raw]
# # Get the list of columns that have NaN values
# columns_with_nan = delhi.columns[delhi.isna().any()].tolist()
# columns_with_nan

# %%
import pandas as pd
from pykrige.ok import OrdinaryKriging
import numpy as np

def estimate_pollutant(df, date_column, nlags=20):
    # Create a DataFrame with only latitude, longitude, and the specified date column
    df1 = df[['longitude', 'latitude', date_column]]

    # Create a DataFrame with latitude and longitude where the specified date column's values are NaN
    nan_locations_df = df1[df1[date_column].isna()][['longitude', 'latitude']]

    # Create a DataFrame with latitude, longitude, and the specified date column excluding NaN values
    pollutant_df = df1.dropna(subset=[date_column])[['longitude', 'latitude', date_column]]

    # Prepare the data for Ordinary Kriging
    lons = np.array(pollutant_df['longitude'])
    lats = np.array(pollutant_df['latitude'])
    zdata = np.array(pollutant_df[date_column])

    # Perform Ordinary Kriging
    OK = OrdinaryKriging(lons, lats, zdata, variogram_model='linear', verbose=True, enable_plotting=False, nlags=nlags)
    grid_lon = np.array(nan_locations_df["longitude"])
    grid_lat = np.array(nan_locations_df["latitude"])
    z1, ss1 = OK.execute('grid', grid_lon, grid_lat)

    # Fill in NaN values in the specified date column with the interpolated values
    nan_locations_df[date_column] = z1[0]

    # Merge the two DataFrames based on their indices
    merged_df = pd.concat([pollutant_df, nan_locations_df], ignore_index=False)

    # Sort the DataFrame by ascending index
    merged_df = merged_df.sort_index(ascending=True)

    return merged_df

# %%
# df should be the DataFrame with columns containing NaN values
df = pd.read_csv("/home/sysadm/Downloads/sentinal5p_Hcho/Chosen_state_2023_sep_merge_sentinel5p_Hcho/Delhi_sep_Hcho.csv")

# Get the list of columns that have NaN values
columns_with_nan = df.columns[df.isna().any()].tolist()

# Create an empty dictionary to store the estimated AOD DataFrames
estimated_data = {}

# Iterate through the columns with NaN values and apply estimate_aod
for date_column in columns_with_nan:
    estimated_data[date_column] = estimate_pollutant(df, date_column)

# Create a list of columns to keep in the estimated_df
columns_to_keep = ['longitude', 'latitude'] + columns_with_nan

# Select only the desired columns from the estimated_df
estimated_df = pd.concat([estimated_data[date_column] for date_column in columns_with_nan], axis=1)
estimated_df = estimated_df[columns_to_keep]

# Drop the duplicate 'latitude' and 'longitude' columns
estimated_df = estimated_df.loc[:,~estimated_df.columns.duplicated()]

# Create a DataFrame 'original_df' containing the original columns without NaN values
original_columns = df.columns.difference(columns_with_nan).tolist()
original_df = df[original_columns]
# Merge the estimated_df and original_df based on 'latitude' and 'longitude'
result_df = original_df.merge(estimated_df, on=['longitude', 'latitude'], how = 'inner')
result_df.to_csv("/home/sysadm/Downloads/sentinal5p_Hcho/After_krigging_2023_sep_sentinal5p_Hcho/Delhi_2023_sep_O3_final.csv",index = False)
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 4.007694721280691e-08
# Nugget: 2.739228677521688e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 8.093470078632584e-08
# Nugget: 4.4466308171877e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 2.9571824070387083e-08
# Nugget: 1.1729311122433284e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 5.133011029332808e-08
# Nugget: 2.473254119924652e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 2.008245855559918e-08
# Nugget: 9.127789148619368e-09
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 4.071589205036414e-08
# Nugget: 7.197678967703232e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 3.652330087361427e-08
# Nugget: 1.649027701881212e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.6683423706595262e-07
# Nugget: 2.619797970577841e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 2.844736278903178e-08
# Nugget: 1.77043006240681e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.4851382790684727e-07
# Nugget: 2.506691850191138e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.3243159334405138e-08
# Nugget: 1.0779389098928629e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 8.628580140064127e-08
# Nugget: 5.096773463781588e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.928566976028464e-07
# Nugget: 4.556473887362593e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 2.3235113149164724e-08
# Nugget: 2.591403117057947e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.4837427753945718e-07
# Nugget: 7.492302823870803e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.3902619062596962e-08
# Nugget: 1.1912123636155366e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.2675544622790453e-08
# Nugget: 1.6849946735627013e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 4.949042239263002e-08
# Nugget: 2.4359426316066513e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 5.7561350342652734e-08
# Nugget: 1.9238846158631945e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 7.558969382134904e-08
# Nugget: 5.4824133479909235e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 2.5736966983209547e-07
# Nugget: 8.589591799884388e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.2785075922522362e-08
# Nugget: 1.5353956656265625e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 6.721121547807931e-08
# Nugget: 6.535707506530991e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 2.0001470960025872e-07
# Nugget: 3.849767676135409e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 4.287472216708322e-08
# Nugget: 7.822713151748084e-09
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 8.947184320919988e-09
# Nugget: 1.4289675746563165e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.668794462803785e-07
# Nugget: 3.189679331690493e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 2.9959885720217144e-08
# Nugget: 2.7195205053734432e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 3.7062556988423746e-08
# Nugget: 4.05281035608595e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...

# %%
result_df
# Out:
#       2023-09-26  latitude  longitude  2023-09-01  2023-09-02  2023-09-03  \
# 0       0.000240    28.551     76.849    0.000297    0.000114    0.000219
# 1      -0.000105    28.561     76.849    0.000153    0.000206    0.000249
# 2       0.000331    28.571     76.849    0.000143    0.000114    0.000031
# 3       0.000042    28.580     76.849    0.000181    0.000114   -0.000144
# 4       0.000125    28.551     76.860    0.000572   -0.000008    0.000056
# ...          ...       ...        ...         ...         ...         ...
# 1345    0.000152    28.688     77.327    0.000022    0.000298    0.000100
# 1346    0.000371    28.512     77.337   -0.000008    0.000086    0.000070
# 1347    0.000193    28.522     77.337    0.000144    0.000334   -0.000003
# 1348    0.000388    28.610     77.337    0.000089    0.000092    0.000070
# 1349    0.000197    28.619     77.337    0.000460    0.000038    0.000143
#
#       2023-09-04  2023-09-05  2023-09-06  2023-09-07  ...  2023-09-20  \
# 0       0.000136    0.000206    0.000574   -0.000137  ...    0.000182
# 1      -0.000127    0.000034    0.000491    0.000123  ...   -0.000028
# 2       0.000098    0.000107    0.000524    0.000025  ...    0.000225
# 3       0.000111    0.000107    0.000188   -0.000044  ...    0.000081
# 4       0.000085    0.000294    0.000351    0.000268  ...    0.000092
# ...          ...         ...         ...         ...  ...         ...
# 1345    0.000136    0.000104    0.000216    0.000210  ...   -0.000080
# 1346    0.000149    0.000026    0.000439    0.000173  ...    0.000524
# 1347    0.000242    0.000053    0.000239    0.000110  ...    0.000093
# 1348    0.000149    0.000145    0.000483   -0.000012  ...    0.000210
# 1349    0.000134    0.000105    0.000431    0.000107  ...    0.000065
#
#       2023-09-21  2023-09-22  2023-09-23  2023-09-24  2023-09-25  2023-09-27  \
# 0       0.000526    0.000171    0.000057    0.000154    0.000093    0.000192
# 1       0.000085    0.000001    0.000351   -0.000010    0.000118    0.000092
# 2       0.000709    0.000121    0.000030    0.000299    0.000090    0.000358
# 3       0.000234    0.000097    0.000465    0.000214    0.000020   -0.000112
# 4       0.001077    0.000504    0.000212    0.000371    0.000134    0.000106
# ...          ...         ...         ...         ...         ...         ...
# 1345    0.000431    0.000017    0.000976    0.000151    0.000287   -0.000011
# 1346    0.000204    0.000193    0.000422    0.000041    0.000047    0.000173
# 1347    0.000078    0.000067    0.000115    0.000214    0.000016    0.000197
# 1348    0.000647    0.000407    0.000317    0.000065    0.000041    0.000194
# 1349    0.000418    0.000118   -0.000050   -0.000018    0.000168    0.000207
#
#       2023-09-28  2023-09-29  2023-09-30
# 0       0.000310   -0.000114    0.000046
# 1       0.000636    0.000099   -0.000158
# 2       0.000381    0.000172    0.000229
# 3       0.000139    0.000402    0.000063
# 4       0.000148    0.000134   -0.000001
# ...          ...         ...         ...
# 1345    0.000202    0.000082    0.000205
# 1346   -0.000014    0.000173    0.000660
# 1347   -0.000002    0.000173    0.000269
# 1348    0.000284    0.000496    0.000194
# 1349    0.000108    0.000670   -0.000090
#
# [1350 rows x 32 columns]

# %%
# df should be the DataFrame with columns containing NaN values
df = pd.read_csv("/home/sysadm/Downloads/sentinal5p_Hcho/Chosen_state_2023_sep_merge_sentinel5p_Hcho/WB_sep_Hcho.csv")

# Get the list of columns that have NaN values
columns_with_nan = df.columns[df.isna().any()].tolist()

# Create an empty dictionary to store the estimated AOD DataFrames
estimated_data = {}

# Iterate through the columns with NaN values and apply estimate_aod
for date_column in columns_with_nan:
    estimated_data[date_column] = estimate_pollutant(df, date_column)

# Create a list of columns to keep in the estimated_df
columns_to_keep = ['longitude', 'latitude'] + columns_with_nan

# Select only the desired columns from the estimated_df
estimated_df = pd.concat([estimated_data[date_column] for date_column in columns_with_nan], axis=1)
estimated_df = estimated_df[columns_to_keep]

# Drop the duplicate 'latitude' and 'longitude' columns
estimated_df = estimated_df.loc[:,~estimated_df.columns.duplicated()]

# Create a DataFrame 'original_df' containing the original columns without NaN values
original_columns = df.columns.difference(columns_with_nan).tolist()
original_df = df[original_columns]
# Merge the estimated_df and original_df based on 'latitude' and 'longitude'
result_df = original_df.merge(estimated_df, on=['longitude', 'latitude'], how = 'inner')
result_df.to_csv("/home/sysadm/Downloads/sentinal5p_Hcho/After_krigging_2023_sep_sentinal5p_Hcho/WB_2023_sep_O3_final.csv",index = False)
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 3.951402000181847e-09
# Nugget: 4.5246303362898456e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.5998827582284206e-09
# Nugget: 1.9373432067197393e-08
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...

# %%
result_df
